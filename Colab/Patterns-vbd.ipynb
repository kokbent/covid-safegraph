# %% [markdown]
# # Create SDM Patterns with visits by day

# %%
import pandas as pd

destination = '/content/gdrive/My Drive/safegraph-patterns' #enter your desired Google Drive folder without a '/' at the end

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
months = ['2019-12']
for x in months:
  df = pd.read_csv(destination + '/' + x + '/patterns.csv')
  df = df[['safegraph_place_id', 'poi_cbg', 'visits_by_day', 'raw_visit_counts', 'raw_visitor_counts']]
  df.to_csv(destination + '/output/' + 'patterns-vbd-' + x + '.csv')

# %%
x = '2020-01'
df = pd.read_csv(destination + '/' + x + '/patterns.csv')

# %%
df
# Out:
#         Unnamed: 0  ...                device_type
# 0                2  ...  {"android":335,"ios":205}
# 1               27  ...     {"android":16,"ios":9}
# 2               28  ...  {"android":106,"ios":115}
# 3               33  ...      {"android":4,"ios":4}
# 4               51  ...    {"android":77,"ios":44}
# ...            ...  ...                        ...
# 279851     1038829  ...   {"android":69,"ios":129}
# 279852     1038830  ...     {"android":14,"ios":5}
# 279853     1038882  ...     {"android":15,"ios":0}
# 279854     1038899  ...    {"android":15,"ios":30}
# 279855     1038922  ...   {"android":107,"ios":51}
#
# [279856 rows x 27 columns]
